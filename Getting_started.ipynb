# %% [markdown]
# <a href="https://colab.research.google.com/github/graemeboulton/portfolio/blob/master/Getting_started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
salary = 999

# %%
base_salary = 100000
bonus_rate = 0.1

# %%
total_salary = (base_salary)*(bonus_rate)

# %%
total_salary
# Out:
# 10000.0

# %%
total_salary = (base_salary)*(2 + bonus_rate)

# %%
company_name = 'Boulton Data'

# %%
job_id = 1
job_title = 'data analyst'
job_salary = 60000
job_wfh = True

# %%
print("Job Description")
print("-------------")
print("Company", company_name)
print("Job ID:", job_id)
print("job Title", job_title)
print("Salary", job_salary)
print("WFH?", job_wfh)
# Out:
# Job Description
# -------------
# Company Boulton Data
# Job ID: 1
# job Title data analyst
# Salary 60000
# WFH? True
